# %%
from PIL import Image, ImageOps,ImageEnhance
import os
import random
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_path = 'Ai_sample'

# %%
data_list = []

# List all subdirectories (classes) in the main folder
class_folders = [folder for folder in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, folder))]

# Loop through each class folder
for class_folder in class_folders:
    class_folder_path = os.path.join(dataset_path, class_folder)
    image_files = [file for file in os.listdir(class_folder_path) if file.endswith('.jpg') or file.endswith('.png')]
    
    # Add image paths and corresponding classes to the list
    for image_file in image_files:
        image_path = os.path.join(class_folder_path, image_file)
        data_list.append({'Image_Path': image_path, 'Class': class_folder})

# Create DataFrame from the list
image_data = pd.DataFrame(data_list)

# Display the image data DataFrame
print("Image Data:")
image_data.tail()  # Display the first few rows
# Out:
# Image Data:
#                                 Image_Path  Class
# 3  Ai_sample/spoon/IMG-20240429-WA0016.jpg  spoon
# 4    Ai_sample/cup/IMG-20240429-WA0040.jpg    cup
# 5    Ai_sample/cup/IMG-20240429-WA0039.jpg    cup
# 6  Ai_sample/plate/IMG-20240429-WA0027.jpg  plate
# 7  Ai_sample/plate/IMG-20240429-WA0028.jpg  plate

# %%
image_data.shape
# Out:
# (8, 2)

# %%
import os
from PIL import Image, ImageOps, ImageEnhance

def flip_image(image_path, save_path):
    # Open the image
    image = Image.open(image_path)
    # Flip the image horizontally (180 degrees)
    flipped_image = ImageOps.mirror(image)
    # Save the flipped image
    flipped_image.save(save_path)

def color_augmentation(image_path, save_path, brightness_factor=1.5, contrast_factor=1.5):
    # Open the image
    image = Image.open(image_path)
    # Enhance brightness and contrast
    enhancer = ImageEnhance.Brightness(image)
    enhanced_image = enhancer.enhance(brightness_factor)
    enhancer = ImageEnhance.Contrast(enhanced_image)
    final_image = enhancer.enhance(contrast_factor)
    # Save the augmented image
    final_image.save(save_path)

# Define dataset path and augmentation factors
dataset_path = 'MAIN/images'
brightness_factor = 1
contrast_factor = 2.5

# Create output folders if they don't exist
# output_flip_path = dataset_path + '_FLIP'
output_color_path = dataset_path + '_COLOR'
# os.makedirs(output_flip_path, exist_ok=True)
os.makedirs(output_color_path, exist_ok=True)

# Get a list of all image files in the dataset path
image_files = [f for f in os.listdir(dataset_path) if os.path.isfile(os.path.join(dataset_path, f))]

# Loop through each image file
for image_name in image_files:
    image_path = os.path.join(dataset_path, image_name)
    image_name_no_ext, image_ext = os.path.splitext(image_name)
    
    # Define paths for augmented images
    # flipped_save_path = os.path.join(output_flip_path, f'{image_name_no_ext}_flipped{image_ext}')
    color_augmented_save_path = os.path.join(output_color_path, f'{image_name_no_ext}_color_augmented{image_ext}')
    
    # Apply augmentations and save augmented images
    # flip_image(image_path, flipped_save_path)
    color_augmentation(image_path, color_augmented_save_path, brightness_factor, contrast_factor)
    
    # Print progress
    print(f"Augmented and saved images for {image_name}")
# Out:
# Augmented and saved images for IMG-20240502-WA0046.jpg
# Augmented and saved images for IMG_20240504_131900.jpg
# Augmented and saved images for IMG_20240504_135114.jpg
# Augmented and saved images for IMG-20240429-WA0040.jpg
# Augmented and saved images for IMG-20240429-WA0017_rotated.jpg
# Augmented and saved images for IMG_20240504_131857.jpg
# Augmented and saved images for IMG-20240429-WA0043.jpg
# Augmented and saved images for IMG-20240429-WA0044.jpg
# Augmented and saved images for IMG_20240504_135229.jpg
# Augmented and saved images for IMG_20240504_132026.jpg
# Augmented and saved images for IMG_20240504_132238.jpg
# Augmented and saved images for IMG_20240504_131742.jpg
# Augmented and saved images for IMG_20240430_194604.jpg
# Augmented and saved images for IMG_20240430_194942.jpg
# Augmented and saved images for IMG_20240430_201714.jpg
# Augmented and saved images for IMG_20240430_202029_color_augmented.jpg
# Augmented and saved images for IMG_20240504_131714.jpg
# Augmented and saved images for IMG_20240430_202029.jpg
# Augmented and saved images for IMG-20240429-WA0042.jpg
# Augmented and saved images for IMG_20240504_132010.jpg
# Augmented and saved images for IMG_20240504_135329.jpg
# Augmented and saved images for IMG_20240504_135057.jpg
# Augmented and saved images for IMG_20240504_131720.jpg
# Augmented and saved images for IMG_20240504_135321.jpg
# Augmented and saved images for IMG_20240430_194529.jpg
# Augmented and saved images for IMG_20240504_135126.jpg
# Augmented and saved images for IMG-20240502-WA0032.jpg
# Augmented and saved images for IMG-20240502-WA0055.jpg
# Augmented and saved images for IMG-20240502-WA0048.jpg
# Augmented and saved images for IMG_20240504_132202.jpg
# Augmented and saved images for IMG-20240429-WA0032.jpg
# Augmented and saved images for IMG_20240430_194805.jpg
# Augmented and saved images for IMG-20240429-WA0020_rotated.jpg
# Augmented and saved images for IMG_20240504_132136.jpg
# Augmented and saved images for IMG-20240429-WA0016_flipped.jpg
# Augmented and saved images for IMG-20240502-WA0051.jpg
# Augmented and saved images for IMG_20240430_201746.jpg
# Augmented and saved images for IMG_20240504_134908.jpg
# Augmented and saved images for IMG-20240502-WA0017.jpg
# Augmented and saved images for IMG-20240502-WA0042.jpg
# Augmented and saved images for IMG_20240504_131937.jpg
# Augmented and saved images for IMG_20240504_134852.jpg
# Augmented and saved images for IMG-20240502-WA0022.jpg
# Augmented and saved images for IMG-20240429-WA0017.jpg
# Augmented and saved images for IMG_20240430_194931.jpg
# Augmented and saved images for IMG_20240504_135253.jpg
# Augmented and saved images for IMG-20240502-WA0045.jpg
# Augmented and saved images for IMG_20240504_131919.jpg
# Augmented and saved images for IMG-20240502-WA0036.jpg
# Augmented and saved images for IMG_20240504_135142.jpg
# Augmented and saved images for IMG-20240429-WA0030.jpg
# Augmented and saved images for IMG_20240430_194739.jpg
# Augmented and saved images for IMG-20240502-WA0033.jpg
# Augmented and saved images for IMG_20240504_131925.jpg
# Augmented and saved images for IMG_20240430_202023.jpg
# Augmented and saved images for IMG-20240429-WA0019_rotated.jpg
# Augmented and saved images for IMG_20240430_194535.jpg
# Augmented and saved images for IMG-20240502-WA0026.jpg
# Augmented and saved images for IMG_20240504_134925.jpg
# Augmented and saved images for IMG-20240502-WA0039.jpg
# Augmented and saved images for IMG-20240502-WA0043.jpg
# Augmented and saved images for IMG_20240504_132217.jpg
# Augmented and saved images for IMG_20240504_135110.jpg
# Augmented and saved images for IMG_20240504_131945.jpg
# Augmented and saved images for IMG_20240430_202029_rotated.jpg
# Augmented and saved images for IMG-20240502-WA0025.jpg
# Augmented and saved images for IMG-20240502-WA0040.jpg
# Augmented and saved images for IMG_20240430_194544.jpg
# Augmented and saved images for IMG_20240504_131815.jpg
# Augmented and saved images for IMG_20240504_132247.jpg
# Augmented and saved images for IMG-20240502-WA0034.jpg
# Augmented and saved images for IMG_20240430_201643.jpg
# Augmented and saved images for IMG-20240429-WA0036.jpg
# Augmented and saved images for IMG-20240502-WA0041.jpg
# Augmented and saved images for IMG_20240504_135042.jpg
# Augmented and saved images for IMG_20240504_134842.jpg
# Augmented and saved images for IMG_20240430_194936.jpg
# Augmented and saved images for IMG_20240430_194848.jpg
# Augmented and saved images for IMG_20240504_132234.jpg
# Augmented and saved images for IMG_20240504_132012.jpg
# Augmented and saved images for IMG_20240504_132124.jpg
# Augmented and saved images for IMG-20240502-WA0024.jpg
# Augmented and saved images for IMG-20240502-WA0053.jpg
# Augmented and saved images for IMG-20240429-WA0039.jpg
# Augmented and saved images for IMG_20240430_201742.jpg
# Augmented and saved images for IMG-20240429-WA0019.jpg
# Augmented and saved images for IMG-20240429-WA0031.jpg
# Augmented and saved images for IMG_20240504_132004.jpg
# Augmented and saved images for IMG-20240502-WA0027.jpg
# Augmented and saved images for IMG-20240502-WA0056.jpg
# Augmented and saved images for IMG-20240502-WA0031.jpg
# Augmented and saved images for IMG_20240430_194607.jpg
# Augmented and saved images for IMG_20240430_202022_rotated.jpg
# Augmented and saved images for IMG-20240502-WA0049.jpg
# Augmented and saved images for IMG_20240504_131652.jpg
# Augmented and saved images for IMG-20240502-WA0038.jpg
# Augmented and saved images for IMG-20240502-WA0037.jpg
# Augmented and saved images for IMG_20240430_194629.jpg
# Augmented and saved images for IMG_20240430_195001.jpg
# Augmented and saved images for IMG_20240430_201625.jpg
# Augmented and saved images for IMG_20240504_135035.jpg
# Augmented and saved images for IMG_20240504_134922.jpg
# Augmented and saved images for IMG-20240502-WA0050.jpg
# Augmented and saved images for IMG-20240502-WA0047.jpg
# Augmented and saved images for IMG-20240429-WA0020_color_augmented.jpg
# Augmented and saved images for IMG_20240430_194821.jpg
# Augmented and saved images for IMG-20240502-WA0019.jpg
# Augmented and saved images for IMG_20240430_202029_flipped.jpg
# Augmented and saved images for IMG_20240430_201738.jpg
# Augmented and saved images for IMG_20240504_131826.jpg
# Augmented and saved images for IMG-20240429-WA0017_color_augmented.jpg
# Augmented and saved images for IMG_20240430_201631.jpg
# Augmented and saved images for IMG_20240504_131705.jpg
# Augmented and saved images for IMG_20240504_134914.jpg
# Augmented and saved images for IMG-20240502-WA0044.jpg
# Augmented and saved images for IMG-20240502-WA0028.jpg
# Augmented and saved images for IMG-20240429-WA0038.jpg
# Augmented and saved images for IMG-20240429-WA0016_color_augmented.jpg
# Augmented and saved images for IMG_20240504_134928.jpg
# Augmented and saved images for IMG-20240429-WA0019_flipped.jpg
# Augmented and saved images for IMG_20240430_201637.jpg
# Augmented and saved images for IMG_20240504_132053.jpg
# Augmented and saved images for IMG_20240504_131725.jpg
# Augmented and saved images for IMG_20240430_202023_flipped.jpg
# Augmented and saved images for IMG_20240504_135241.jpg
# Augmented and saved images for IMG-20240502-WA0023.jpg
# Augmented and saved images for IMG-20240502-WA0021.jpg
# Augmented and saved images for IMG_20240504_131753.jpg
# Augmented and saved images for IMG-20240429-WA0016.jpg
# Augmented and saved images for IMG-20240429-WA0020_flipped.jpg
# Augmented and saved images for IMG_20240504_131905.jpg
# Augmented and saved images for IMG_20240504_134911.jpg
# Augmented and saved images for IMG_20240504_132045.jpg
# Augmented and saved images for IMG-20240429-WA0017_flipped.jpg
# Augmented and saved images for IMG_20240504_132149.jpg
# Augmented and saved images for IMG-20240429-WA0020.jpg
# Augmented and saved images for IMG_20240504_131834.jpg
# Augmented and saved images for IMG-20240502-WA0054.jpg
# Augmented and saved images for IMG_20240504_131722.jpg
# Augmented and saved images for IMG_20240504_131843.jpg
# Augmented and saved images for IMG-20240429-WA0027.jpg
# Augmented and saved images for IMG-20240429-WA0035.jpg
# Augmented and saved images for IMG_20240430_194917.jpg
# Augmented and saved images for IMG-20240429-WA0033.jpg
# Augmented and saved images for IMG_20240430_194855.jpg
# Augmented and saved images for IMG-20240502-WA0020.jpg
# Augmented and saved images for IMG_20240504_132130.jpg
# Augmented and saved images for IMG-20240429-WA0029.jpg
# Augmented and saved images for IMG-20240502-WA0030.jpg
# Augmented and saved images for IMG-20240429-WA0019_color_augmented.jpg
# Augmented and saved images for IMG_20240504_131659.jpg
# Augmented and saved images for IMG-20240502-WA0029.jpg
# Augmented and saved images for IMG-20240429-WA0016_rotated.jpg
# Augmented and saved images for IMG-20240429-WA0041.jpg
# Augmented and saved images for IMG-20240502-WA0018.jpg
# Augmented and saved images for IMG_20240430_194955.jpg
# Augmented and saved images for IMG_20240504_135214.jpg
# Augmented and saved images for IMG_20240504_132227.jpg
# Augmented and saved images for IMG_20240430_202023_rotated.jpg
# Augmented and saved images for IMG_20240430_194618.jpg
# Augmented and saved images for IMG-20240429-WA0034.jpg
# Augmented and saved images for IMG_20240430_201652.jpg
# Augmented and saved images for IMG_20240430_194909.jpg
# Augmented and saved images for IMG_20240504_132213.jpg
# Augmented and saved images for IMG-20240502-WA0052.jpg
# Augmented and saved images for IMG-20240429-WA0028.jpg
# Augmented and saved images for IMG-20240502-WA0035.jpg
# Augmented and saved images for IMG_20240430_201729.jpg
# Augmented and saved images for IMG_20240504_131738.jpg
# Augmented and saved images for IMG_20240430_201658.jpg
# Augmented and saved images for IMG-20240429-WA0037.jpg
# Augmented and saved images for IMG_20240430_202023_color_augmented.jpg
# Augmented and saved images for IMG_20240430_194747.jpg

# %%
# %pip install copyfile
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting copyfile
#   Downloading copyfile-0.1.1.tar.gz (1.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: copyfile
#   Building wheel for copyfile (setup.py) ... done
#   Created wheel for copyfile: filename=copyfile-0.1.1-py3-none-any.whl size=2012 sha256=1dd16c749b238ab7cfbc58b50f76438c49640d35a33ffca8e7e654e0ff37ac24
#   Stored in directory: /home/umar/.cache/pip/wheels/62/ed/ac/1c149b27a95378aa65bd4f4d34e1fb3ed7b07c920378df96c1
# Successfully built copyfile
# Installing collected packages: copyfile
# Successfully installed copyfile-0.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import errno

def copy_file(src, dest):
    try:
        with open(src, 'rb') as fsrc, open(dest, 'wb') as fdest:
            fdest.write(fsrc.read())
    except IOError as e:
        print(f"Unable to copy file: {e}")

def organize_files(source_folder, destination_folder):
    # Create destination folders if they don't exist
    images_folder = os.path.join(destination_folder, 'images')
    labels_folder = os.path.join(destination_folder, 'labels')
    try:
        os.makedirs(images_folder)
        os.makedirs(labels_folder)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise

    # Iterate through subfolders in the source folder
    for root, dirs, files in os.walk(source_folder):
        for file in files:
            file_path = os.path.join(root, file)
            if file.lower().endswith(('.jpg', '.jpeg')):
                # Copy image files to the images subfolder
                dest_path = os.path.join(images_folder, file)
                copy_file(file_path, dest_path)
            elif file.lower().endswith('.txt'):
                # Copy text files to the labels subfolder
                dest_path = os.path.join(labels_folder, file)
                copy_file(file_path, dest_path)

if __name__ == "__main__":
    source_folder = '/home/umar/Documents/AI/project/AI_dataset_ann'
    destination_folder = '/home/umar/Documents/AI/project/data'

    organize_files(source_folder, destination_folder)
    print("Files organized successfully!")
# Out:
# Files organized successfully!
